# %% [markdown]
# # Mapamundi con diagramas circulares

# %%
import geopandas
import matplotlib.pyplot as plt
import numpy as np

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world = world[(world.name!="Antarctica")]

# Prepare the map
fig, ax = plt.subplots(figsize=(14, 10))
world.plot(ax=ax, color='lightgrey')
# Out:
# C:\Users\juanc\AppData\Local\Temp\ipykernel_6004\3334391754.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
# <Axes: >
